# %%
import pandas as pd

# %%
ds=pd.read_csv("SampleSuperstore.csv")

# %%
ds
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
ds.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [markdown]
# From the above description of data we came to know that:
# 1.we have the data of about 9994 product sold details
# 2.we have 5 numerical fields out of 13 columns

# %%
conda install -c conda-forge pandas-profiling
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\jayas\anaconda3
#
#   added / updated specs:
#     - pandas-profiling
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.11.0               |   py38haa244fe_0        16.9 MB  conda-forge
#     pandas-profiling-1.4.1     |                0          40 KB  conda-forge
#     python_abi-3.8             |           2_cp38           4 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        16.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   pandas-profiling   conda-forge/win-64::pandas-profiling-1.4.1-0
#   python_abi         conda-forge/win-64::python_abi-3.8-2_cp38
#
# The following packages will be UPDATED:
#
# ...

# %%
conda update pandas-profiling
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\jayas\anaconda3
#
#   added / updated specs:
#     - pandas-profiling
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.11.0               |   py38haa95532_0        14.4 MB
#     confuse-1.5.0              |     pyhd3eb1b0_0          23 KB
#     htmlmin-0.1.12             |     pyhd3eb1b0_1          24 KB
#     imagehash-4.2.1            |     pyhd3eb1b0_0         285 KB
#     missingno-0.4.2            |     pyhd3eb1b0_1          15 KB
#     pandas-profiling-2.9.0     |     pyhd3eb1b0_0         168 KB
#     phik-0.11.2                |     pyhd3eb1b0_1         538 KB
#     tangled-up-in-unicode-0.1.0|     pyhd3eb1b0_0         689 KB
#     visions-0.5.0              |     pyhd3eb1b0_0          45 KB
#     xmltodict-0.12.0           |     pyhd3eb1b0_0          13 KB
# ...

# %%
from pandas_profiling import ProfileReport

# %%
report=ProfileReport(ds,explorative=True)

# %%
report.to_file("Data exploration report.html")
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# Executing shutdown due to inactivity...
# 2022-01-03 13:06:46,493 - INFO     - Executing shutdown due to inactivity...
# Executing shutdown...
# 2022-01-03 13:06:50,832 - INFO     - Executing shutdown...

# %% [markdown]
# Detecting and handling outliers

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(ds["Sales"],vert=False)
plt.show()

# %%
plt.boxplot(ds["Profit"],vert=False)
plt.show()

# %%
plt.boxplot(ds["Discount"],vert=False)
plt.show()

# %%
plt.boxplot(ds["Quantity"],vert=False)
plt.show()

# %% [markdown]
# so from the above boxplots it is clear that there are few outliers in above columns ,we have to handle it to draw right insights

# %%
ds1=(ds[ds["Sales"]>1.1])
ds1=ds1[ds1["Sales"]<8000]
ds1
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
plt.boxplot(ds1["Sales"],vert=False)
plt.show()

# %%
print(ds1[ds1["Sales"]>5500])
# Out:
#            Ship Mode    Segment        Country           City           State  \
# 509   Standard Class   Consumer  United States        Atlanta         Georgia
# 683         Same Day  Corporate  United States     Burlington  North Carolina
# 6626  Standard Class   Consumer  United States  New York City        New York
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 509         30318  South  Office Supplies      Binders  6354.95         5
# 683         27217  South       Technology     Machines  7999.98         4
# 6626        10024   East       Technology     Machines  6999.96         4
#
#       Discount     Profit
# 509        0.0  3177.4750
# 683        0.5 -3839.9904
# 6626       0.0  2239.9872

# %%
ds1=ds1[ds1["Sales"]<5500]

# %%
plt.boxplot(ds1["Sales"],vert=False)
plt.show()

# %% [markdown]
#     Now the sales column is free from outliers and we assume that now it is normally distributed

# %% [markdown]
#     We will now do the same for profit also

# %%
ds[ds["Profit"]>2000]
# Out:
#            Ship Mode      Segment        Country           City         State  \
# 509   Standard Class     Consumer  United States        Atlanta       Georgia
# 1085  Standard Class     Consumer  United States        Yonkers      New York
# 2623     First Class  Home Office  United States  New York City      New York
# 4098  Standard Class     Consumer  United States    Minneapolis     Minnesota
# 4190  Standard Class     Consumer  United States         Newark      Delaware
# 4277  Standard Class    Corporate  United States       Lakewood    New Jersey
# 6520    Second Class     Consumer  United States        Jackson      Michigan
# 6626  Standard Class     Consumer  United States  New York City      New York
# 6826  Standard Class    Corporate  United States      Lafayette       Indiana
# 7666  Standard Class  Home Office  United States     Providence  Rhode Island
# 8153     First Class     Consumer  United States        Seattle    Washington
# ...

# %%
ds1=(ds[ds["Profit"]>-2000])
ds1=ds1[ds1["Profit"]<2500]
ds1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9977 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9977 non-null   object
#  1   Segment       9977 non-null   object
#  2   Country       9977 non-null   object
#  3   City          9977 non-null   object
#  4   State         9977 non-null   object
#  5   Postal Code   9977 non-null   int64
#  6   Region        9977 non-null   object
#  7   Category      9977 non-null   object
#  8   Sub-Category  9977 non-null   object
#  9   Sales         9977 non-null   float64
#  10  Quantity      9977 non-null   int64
#  11  Discount      9977 non-null   float64
#  12  Profit        9977 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1.1+ MB

# %%
plt.boxplot(ds1["Profit"],vert=False)
plt.show()

# %% [markdown]
#     After removing outliers we can observe that the density of the products being sold more without profit and loss of amount of loss between 0 to 1300 approximately.
#     We even observe that there are also more products sold at good amount of profit ranging from 0 to 1500.
#     now its all about knowing the factors affecting the profit and the KPI of profit to maximize the sales with objective of increasing the profit and decresing the loss .

# %%
plt.boxplot(ds1["Discount"],vert=False)
plt.show()

# %% [markdown]
#     Here we need to know about what count products we have on discount above 0.5

# %%
ds1[ds1["Discount"]>0.2].describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   1386.000000   1386.000000  1386.000000  1386.000000  1386.000000
# mean   53279.901876    245.546496     3.852814     0.582605   -79.348454
# std    24515.699606    782.967872     2.208283     0.184792   188.887198
# min     1841.000000      0.444000     1.000000     0.300000 -1862.312400
# 25%    32216.000000      8.740000     2.000000     0.400000   -71.370900
# 50%    60610.000000     42.902000     3.000000     0.700000   -18.151800
# 75%    77041.000000    280.782000     5.000000     0.700000    -6.019600
# max    97756.000000  22638.480000    14.000000     0.800000  1119.996800

# %%
plt.scatter(ds1["Discount"],ds1["Profit"])
plt.show()

# %%
plt.scatter(ds1["Sales"],ds1["Profit"])
plt.show()

# %% [markdown]
#     From the above plot we can observe that with discount more than 0.2 per product the supermarket is facing high loss rather than profit.
#     The purpose or the strategy for applying discount might be for selling them asap before thier expiry or to sell them knowing the coming new market and new product models.
#     So we should now try to know the reason of having products unsold for many days or the ones leading to application of discounts which is in turn reducing the profit and brings loss.

# %%
plt.bar(ds1["Ship Mode"],ds1["Profit"])
plt.show()

# %%
plt.bar(ds1["Category"],ds1["Profit"])
plt.show()
